# %%
import kagglehub

path = kagglehub.dataset_download("seonyseony/alleyfloodnet")
print("Dataset path:", path)
# Out:
# ...
# 100%|██████████| 64.0M/64.0M [00:00<00:00, 129MB/s]
# Extracting files...
# Dataset path: /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1

# %%
import os

for root, dirs, files in os.walk(path):
    print(root, "Folders:", dirs, "Files:", len(files))
# Out:
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1 Folders: ['AlleyFloodNet'] Files: 0
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet Folders: ['flood_train_', 'flood_test_'] Files: 0
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet/flood_train_ Folders: ['non_flooded', 'flooded'] Files: 0
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet/flood_train_/non_flooded Folders: [] Files: 380
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet/flood_train_/flooded Folders: [] Files: 468
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet/flood_test_ Folders: ['non_flooded', 'flooded'] Files: 0
# /root/.cache/kagglehub/datasets/seonyseony/alleyfloodnet/versions/1/AlleyFloodNet/flood_test_/non_flooded Folders: [] Files: 129
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

train_dir = path + "/AlleyFloodNet/flood_train_"
test_dir = path + "/AlleyFloodNet/flood_test_"

IMG_SIZE = (224,224)
BATCH_SIZE = 32

train_ds = image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

print(train_ds.class_names)
# Out:
# Found 848 files belonging to 2 classes.
# Found 262 files belonging to 2 classes.
# ['flooded', 'non_flooded']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras import layers, models

cnn_model = models.Sequential([

    layers.Rescaling(1./255, input_shape=(224,224,3)),

    layers.Conv2D(32,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(128,activation='relu'),

    layers.Dropout(0.5),

    layers.Dense(1,activation='sigmoid')

])

cnn_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

cnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ...

# %%
cnn_history = cnn_model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=5
)
# Out:
# Epoch 1/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - accuracy: 0.5448 - loss: 0.8958 - val_accuracy: 0.5076 - val_loss: 0.6909
# Epoch 2/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.5660 - loss: 0.6912 - val_accuracy: 0.6756 - val_loss: 0.6677
# Epoch 3/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.6427 - loss: 0.6365 - val_accuracy: 0.6565 - val_loss: 0.6260
# Epoch 4/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.7453 - loss: 0.5299 - val_accuracy: 0.7137 - val_loss: 0.5823
# Epoch 5/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.7182 - loss: 0.5578 - val_accuracy: 0.6947 - val_loss: 0.5510

# %%
cnn_loss, cnn_acc = cnn_model.evaluate(test_ds)

print("CNN Accuracy =", cnn_acc)
print("CNN Loss =", cnn_loss)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 894ms/step - accuracy: 0.6947 - loss: 0.5510
# CNN Accuracy = 0.694656491279602
# CNN Loss = 0.5510390996932983

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
# Preprocess images for ResNet50
resnet_train = train_ds.map(lambda x, y: (preprocess_input(x), y))
resnet_test = test_ds.map(lambda x, y: (preprocess_input(x), y))

# %%
# Build ResNet50 model
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

resnet_model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])

resnet_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

resnet_model.summary()
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ...

# %%
resnet_history = resnet_model.fit(
    resnet_train,
    validation_data=resnet_test,
    epochs=5
)
# Out:
# Epoch 1/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 231s 8s/step - accuracy: 0.8290 - loss: 0.3969 - val_accuracy: 0.8626 - val_loss: 0.2926
# Epoch 2/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 221s 8s/step - accuracy: 0.9363 - loss: 0.1824 - val_accuracy: 0.9046 - val_loss: 0.2535
# Epoch 3/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 177s 7s/step - accuracy: 0.9552 - loss: 0.1230 - val_accuracy: 0.8969 - val_loss: 0.2354
# Epoch 4/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 202s 7s/step - accuracy: 0.9682 - loss: 0.0962 - val_accuracy: 0.9084 - val_loss: 0.2495
# Epoch 5/5
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 177s 7s/step - accuracy: 0.9693 - loss: 0.0786 - val_accuracy: 0.9122 - val_loss: 0.2518

# %%
resnet_loss, resnet_acc = resnet_model.evaluate(resnet_test)

print("ResNet50 Accuracy =", resnet_acc)
print("ResNet50 Loss =", resnet_loss)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - accuracy: 0.9122 - loss: 0.2518
# ResNet50 Accuracy = 0.9122137427330017
# ResNet50 Loss = 0.25184082984924316

# %%
print("Final Model Comparison")
print("----------------------")
print("CNN Accuracy:", round(cnn_acc, 4))
print("CNN Loss:", round(cnn_loss, 4))
print("ResNet50 Accuracy:", round(resnet_acc, 4))
print("ResNet50 Loss:", round(resnet_loss, 4))
# Out:
# Final Model Comparison
# ----------------------
# CNN Accuracy: 0.6947
# CNN Loss: 0.551
# ResNet50 Accuracy: 0.9122
# ResNet50 Loss: 0.2518

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Testing Accuracy')
plt.title('CNN Accuracy Diagram')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Testing Loss')
plt.title('CNN Loss Diagram')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(resnet_history.history['accuracy'], label='Training Accuracy')
plt.plot(resnet_history.history['val_accuracy'], label='Testing Accuracy')
plt.title('ResNet50 Accuracy Diagram')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(resnet_history.history['loss'], label='Training Loss')
plt.plot(resnet_history.history['val_loss'], label='Testing Loss')
plt.title('ResNet50 Loss Diagram')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
